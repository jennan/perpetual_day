# %% [markdown]
# # Data Pipeline
#
# This notebook showcases the input [PyEarthTools](https://github.com/ACCESS-Community-Hub/PyEarthTools) pipeline used to fetched the data used in this project.
#
# Check out [pipeline.py](src/pipeline.py) to see how this pipeline has been created.

# %%
# needed on ARE to be in the repo folder
# %cd ~/perpetual_day/
# Out:
# /home/551/mr3857/perpetual_day

# %%
import pyearthtools.pipeline as petpipe
import matplotlib.pyplot as plt

from src.pipeline import full_pipeline

# %%
date_range = petpipe.iterators.DateRange('20200101T0000', '20200101T0200', interval='30 minutes')
bbox = [-35.27, -34, 150, 151.27]
cachedir = "/scratch/nf33/mr3857/cache2"

# %%
fullpipe = full_pipeline(date_range, bbox, cachedir)

# %%
fullpipe
# Out:
# <div><svg style="position: absolute; width: 0; height: 0; overflow: hidden">
#     <defs>
#     <symbol id="icon-database" viewBox="0 0 32 32">
#     <path d="M16 0c-8.837 0-16 2.239-16 5v4c0 2.761 7.163 5 16 5s16-2.239 16-5v-4c0-2.761-7.163-5-16-5z"></path>
#     <path d="M16 17c-8.837 0-16-2.239-16-5v6c0 2.761 7.163 5 16 5s16-2.239 16-5v-6c0 2.761-7.163 5-16 5z"></path>
#     <path d="M16 26c-8.837 0-16-2.239-16-5v6c0 2.761 7.163 5 16 5s16-2.239 16-5v-6c0 2.761-7.163 5-16 5z"></path>
#     </symbol>
#     <symbol id="icon-file-text2" viewBox="0 0 32 32">
# ...

# %%
features, targets = next(iter(fullpipe))
print(f"features shape and type: {features.shape}, {features.dtype}")
print(f"targets shape and type: {targets.shape}, {targets.dtype}")
# Out:
# features shape and type: (9, 128, 128), float32
# targets shape and type: (1, 128, 128), float32
# CPU times: user 18.4 ms, sys: 4.93 ms, total: 23.3 ms
# Wall time: 25.5 ms

# %%
_, axes = plt.subplots(3, 3, layout="constrained", figsize=(8, 9), sharex=True, sharey=True)
for ax, chan in zip(axes.flat, features):
    ax.imshow(chan)

# %%
_, axes = plt.subplots()
axes.imshow(targets[0])
